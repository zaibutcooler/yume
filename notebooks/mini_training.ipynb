# %%
from yume import Yume
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from yume import Yume
#
# ModuleNotFoundError: No module named 'yume'
